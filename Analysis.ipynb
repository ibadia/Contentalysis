# %%
from collections import Counter

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
data=pd.read_csv("mangobaazTesting.csv")
data.head()
# Out:
#                   Date         Author  \
# 0  2019-02-04 00:00:00     Nai Dulhan
# 1  2019-01-21 00:00:00    Maliha Khan
# 2  2019-02-08 00:00:00  Rameeza Ahmad
# 3  2019-01-09 00:00:00       Biya Haq
# 4  2018-11-29 00:00:00     Sadia Khan
#
#                                             Headline  \
# 0  \nHere’s What Your Weekly Horoscope Says About...
# 1  \nHere’s What Your Weekly Love Horoscope Says ...
# 2  \nYouTuber Mubeen From Bekaar Films Just Said ...
# 3  \nYouTuber 'Awesamo' Just Bought His Parents A...
# 4  \nPashtuns Are Really Excited That Mark Weins ...
#
#                                              Article  \
# 0  Hello frenz  weekly kismet ka haal dekh lain  ...
# 1  Your weekly love horoscope to guide your dil k...
# 2  Bekaar Films walay bhai ke saath kitni bekaar ...
# 3  I’m not crying  you are. For many of us  growi...
# 4  Mark Weins travelled across Pakistan and taste...
#
#                                                  url
# ...

# %%
article_word_frequency=Counter(' '.join(data.Headline).replace('\n',' ').split(' '))
headline_word_freuency=Counter(' '.join(data.Article).replace('\n',' ').split(' '))

# %%
del article_word_frequency['']
article_word_frequency
# Out:
# Counter({'Here’s': 3,
#          'What': 4,
#          'Your': 4,
#          'Weekly': 3,
#          'Horoscope': 3,
#          'Says': 3,
#          'About': 4,
#          'This': 5,
#          'Week': 3,
#          '|': 3,
#          '4th': 1,
#          'February': 2,
#          '–': 3,
#          '10th': 1,
#          '2019': 3,
#          'Love': 4,
#          '21st': 1,
#          'January': 4,
#          '27th': 1,
#          'YouTuber': 2,
#          'Mubeen': 1,
#          'From': 1,
#          'Bekaar': 1,
#          'Films': 1,
#          'Just': 2,
#          'Said': 1,
#          'Authorities': 1,
#          'Destroyed': 1,
#          'His': 5,
#          'Food': 1,
#          'Truck': 1,
#          'Because': 1,
#          'Of': 3,
#          'Corruption': 1,
#          "'Awesamo'": 1,
#          'Bought': 1,
#          'Parents': 1,
#          'A': 6,
#          'New': 3,
#          'Home': 1,
#          'But': 1,
#          'Whole': 1,
#          'Life': 1,
# ...

# %%
# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate_from_frequencies(article_word_frequency)
 
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
